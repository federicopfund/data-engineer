# %%
import pandas as pd

# %%
#Leo producto unico
prod_unico = pd.read_csv('Datasets locales/Producto_Unico.csv')
prod_unico.head()
# Out:
#    Cod_Producto                                 Producto  Cod_Subcategoria  \
# 0             1               Casco deportivo: 100, rojo                31
# 1             2              Casco deportivo: 100, negro                31
# 2             3  Calcetines para bicicleta de montaña, M                23
# 3             4  Calcetines para bicicleta de montaña, G                23
# 4             5               Casco deportivo: 100, azul                31
#
#    Cod_Categoria
# 0              4
# 1              4
# 2              3
# 3              3
# 4              4

# %%
#leo producto sucursal y stock
prod_suc = pd.read_csv('Datasets locales/Producto_Sucursales.csv')
prod_suc.head(10)
# Out:
#    Cod_Producto  Cod_Sucursal  Stock  Stock_Inicial
# 0             1             1      0              0
# 1             1             2      0              0
# 2             1             3      1              1
# 3             1             4      1              1
# 4             1             5      2              2
# 5             1             6      0              0
# 6             1             7      1              1
# 7             1             8      2              2
# 8             1             9      3              3
# 9             1            10      2              2

# %%
prod_suc2 = prod_suc.copy()
prod_suc2
# Out:
#       Cod_Producto  Cod_Sucursal  Stock  Stock_Inicial
# 0                1             1      0              0
# 1                1             2      0              0
# 2                1             3      1              1
# 3                1             4      1              1
# 4                1             5      2              2
# ...            ...           ...    ...            ...
# 2365           237             6      0              0
# 2366           237             7      1              1
# 2367           237             8      1              1
# 2368           237             9      0              0
# 2369           237            10      0              0
#
# [2370 rows x 4 columns]

# %%
prod_unico2 = prod_unico.copy()
prod_unico2
# Out:
#      Cod_Producto                                 Producto  Cod_Subcategoria  \
# 0               1               Casco deportivo: 100, rojo                31
# 1               2              Casco deportivo: 100, negro                31
# 2               3  Calcetines para bicicleta de montaña, M                23
# 3               4  Calcetines para bicicleta de montaña, G                23
# 4               5               Casco deportivo: 100, azul                31
# ..            ...                                      ...               ...
# 232           233                       Eje de pedalier GM                 5
# 233           234                       Eje de pedalier GA                 5
# 234           235                Carretera: 750, negra, 44                 2
# 235           236                Carretera: 750, negra, 48                 2
# 236           237                Carretera: 750, negra, 52                 2
#
#      Cod_Categoria
# 0                4
# ...

# %%
num = 1
prod_suc2 = prod_suc2.drop(prod_suc2[prod_suc2['Cod_Producto']==num].index)
prod_unico2 = prod_unico2.drop(prod_unico2[prod_unico2['Cod_Producto']==num].index)
prod_suc2
# Out:
#       Cod_Producto  Cod_Sucursal  Stock  Stock_Inicial
# 10               2             1      1              1
# 11               2             2      1              1
# 12               2             3      3              3
# 13               2             4      0              0
# 14               2             5      3              3
# ...            ...           ...    ...            ...
# 2365           237             6      0              0
# 2366           237             7      1              1
# 2367           237             8      1              1
# 2368           237             9      0              0
# 2369           237            10      0              0
#
# [2360 rows x 4 columns]

# %%
prod_unico2
# Out:
#      Cod_Producto                                 Producto  Cod_Subcategoria  \
# 1               2              Casco deportivo: 100, negro                31
# 2               3  Calcetines para bicicleta de montaña, M                23
# 3               4  Calcetines para bicicleta de montaña, G                23
# 4               5               Casco deportivo: 100, azul                31
# 5               6    Jersey con logotipo de manga larga, P                21
# ..            ...                                      ...               ...
# 232           233                       Eje de pedalier GM                 5
# 233           234                       Eje de pedalier GA                 5
# 234           235                Carretera: 750, negra, 44                 2
# 235           236                Carretera: 750, negra, 48                 2
# 236           237                Carretera: 750, negra, 52                 2
#
#      Cod_Categoria
# 1                4
# ...

# %%
prod_unico2['Cod_Producto'] = range(1, 1+len(prod_unico2))
prod_unico2
# Out:
#      Cod_Producto                                 Producto  Cod_Subcategoria  \
# 1               1              Casco deportivo: 100, negro                31
# 2               2  Calcetines para bicicleta de montaña, M                23
# 3               3  Calcetines para bicicleta de montaña, G                23
# 4               4               Casco deportivo: 100, azul                31
# 5               5    Jersey con logotipo de manga larga, P                21
# ..            ...                                      ...               ...
# 232           232                       Eje de pedalier GM                 5
# 233           233                       Eje de pedalier GA                 5
# 234           234                Carretera: 750, negra, 44                 2
# 235           235                Carretera: 750, negra, 48                 2
# 236           236                Carretera: 750, negra, 52                 2
#
#      Cod_Categoria
# 1                4
# ...

# %%
#-------------------------------------------AGREGAR PRODUCTO NUEVO------------------------------------------------------------------------------------------------------

# %%
prod_unico_add = prod_unico.copy()
prod_unico_add
# Out:
#      Cod_Producto                                 Producto  Cod_Subcategoria  \
# 0               1               Casco deportivo: 100, rojo                31
# 1               2              Casco deportivo: 100, negro                31
# 2               3  Calcetines para bicicleta de montaña, M                23
# 3               4  Calcetines para bicicleta de montaña, G                23
# 4               5               Casco deportivo: 100, azul                31
# ..            ...                                      ...               ...
# 232           233                       Eje de pedalier GM                 5
# 233           234                       Eje de pedalier GA                 5
# 234           235                Carretera: 750, negra, 44                 2
# 235           236                Carretera: 750, negra, 48                 2
# 236           237                Carretera: 750, negra, 52                 2
#
#      Cod_Categoria
# 0                4
# ...

# %%
prod_suc_add = prod_suc.copy()
prod_suc_add
# Out:
#       Cod_Producto  Cod_Sucursal  Stock  Stock_Inicial
# 0                1             1      0              0
# 1                1             2      0              0
# 2                1             3      1              1
# 3                1             4      1              1
# 4                1             5      2              2
# ...            ...           ...    ...            ...
# 2365           237             6      0              0
# 2366           237             7      1              1
# 2367           237             8      1              1
# 2368           237             9      0              0
# 2369           237            10      0              0
#
# [2370 rows x 4 columns]

# %%
prod = "Camiseta verde talla L"
subcat = 23
cat = 3
prod_unico_add.loc[len(prod_unico_add)]=[1+len(prod_unico_add),prod,subcat,cat]

# %%
max = prod_suc_add['Cod_Producto'].max() 
for i in range(10):
    prod_suc_add.loc[len(prod_suc_add)]=[max+1,i+1,0,0]
# Out:
#       Cod_Producto  Cod_Sucursal  Stock  Stock_Inicial
# 0                1             1      0              0
# 1                1             2      0              0
# 2                1             3      1              1
# 3                1             4      1              1
# 4                1             5      2              2
# ...            ...           ...    ...            ...
# 2375           238             6      0              0
# 2376           238             7      0              0
# 2377           238             8      0              0
# 2378           238             9      0              0
# 2379           238            10      0              0
#
# [2380 rows x 4 columns]

# %%
prod_unico_add
# Out:
#      Cod_Producto                                 Producto  Cod_Subcategoria  \
# 0               1               Casco deportivo: 100, rojo                31
# 1               2              Casco deportivo: 100, negro                31
# 2               3  Calcetines para bicicleta de montaña, M                23
# 3               4  Calcetines para bicicleta de montaña, G                23
# 4               5               Casco deportivo: 100, azul                31
# ..            ...                                      ...               ...
# 233           234                       Eje de pedalier GA                 5
# 234           235                Carretera: 750, negra, 44                 2
# 235           236                Carretera: 750, negra, 48                 2
# 236           237                Carretera: 750, negra, 52                 2
# 237           238                   Camiseta verde talla L                23
#
#      Cod_Categoria
# 0                4
# ...

# %%
prod_suc_add.tail(20)
# Out:
#       Cod_Producto  Cod_Sucursal  Stock  Stock_Inicial
# 2360           237             1      1              1
# 2361           237             2      0              0
# 2362           237             3      0              0
# 2363           237             4      1              1
# 2364           237             5      0              0
# 2365           237             6      0              0
# 2366           237             7      1              1
# 2367           237             8      1              1
# 2368           237             9      0              0
# 2369           237            10      0              0
# 2370           238             1      0              0
# 2371           238             2      0              0
# 2372           238             3      0              0
# 2373           238             4      0              0
# 2374           238             5      0              0
# 2375           238             6      0              0
# ...
