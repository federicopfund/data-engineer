# %%
# El hostname se obtiene en la seccion overview del sqlserver
jdbcHostname = "grouponesqlserver-379320670.database.windows.net"
# Nombre de la db
jdbcDatabase = "groupOneSqlServerDatabase"
# Siempre es este puerto
jdbcPort = 1433

jdbcUrl = f"jdbc:sqlserver://{jdbcHostname}:{jdbcPort};database={jdbcDatabase}"
print(jdbcUrl)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">jdbc:sqlserver://grouponesqlserver-379320670.database.windows.net:1433;database=groupOneSqlServerDatabase
# </div>

# %%
# Credenciales de acceso a sqlserver
user = "sqlgrupo1"
password = "Passwordgrupo1!"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Lectura de la tabla dbo.Categoria
categoria_table = (spark.read
  .format("jdbc")
  .option("url", jdbcUrl)
  .option("dbtable", "dbo.Categoria")
  .option("user", user)
  .option("password", password)
  .load()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
categoria_table.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Cod_Categoria: string (nullable = true)
# -- Categoria: string (nullable = true)
#
# </div>

# %%
display(categoria_table)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Cod_Categoria</th><th>Categoria</th></tr></thead><tbody><tr><td>1</td><td>Bicicleta</td></tr><tr><td>2</td><td>Componente</td></tr><tr><td>3</td><td>Prenda</td></tr><tr><td>4</td><td>Accesorio</td></tr></tbody></table></div>

# %%
# Transformacion 1: renombrar el campo Categoria a Nombre_Categoria
categoriaTransformada = categoria_table.withColumnRenamed("Categoria", "Nombre_Categoria")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(categoriaTransformada)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Cod_Categoria</th><th>Nombre_Categoria</th></tr></thead><tbody><tr><td>1</td><td>Bicicleta</td></tr><tr><td>2</td><td>Componente</td></tr><tr><td>3</td><td>Prenda</td></tr><tr><td>4</td><td>Accesorio</td></tr></tbody></table></div>

# %%
categoriaTransformada.write.saveAsTable("CategoriaTransformada")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Tabla local de databricks
createLocalTable = f'''
CREATE TABLE IF NOT EXISTS Transformacion
USING org.apache.spark.sql.jdbc
OPTIONS (
    url '{jdbcUrl}',
    dbtable '{"dbo.Transformacion1"}',
    user '{user}',
    password '{password}',
    loginTimeout = 120
    ) '''

#print(createLocalTable)
spark.sql(createLocalTable)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: DataFrame[]</div>

# %%
# %sql
INSERT INTO Transformacion
SELECT * FROM CategoriaTransformada;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
