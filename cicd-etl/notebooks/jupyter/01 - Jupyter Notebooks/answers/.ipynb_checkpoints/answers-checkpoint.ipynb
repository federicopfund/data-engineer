# %% [markdown]
# # Answers
#
# This notebook contains all answers to all questions in the Ansys Introduction to Python course.
#
# The notebook is designed to run in a folder called `answers/` within the course materials folder. Any exercises dealing with file paths will reflect this. If they do not, the reason will be explicitly stated in the answer.
#
# Finally these "answers" are not model answers but suggested answers. There are many ways to solve many of these problems and some will be better than what's shown here. It is advised that these answers not be taken too much to heart. In particular answers try not to use any features of the language that you wouldn't know at that point in the course. Many questions would probably be answered differently on a second pass!

# %% [markdown]
# # Lesson 01 Fundamentals
#
# ## Exercise 01.1

# %%
var1 = 1 + 2 + 3 + 4 + 5
var2 = var1/2
var3 = 'one'

var1, var2, var3
# Out:
# (15, 7.5, 'one')

# %% [markdown]
# ## Exercise 01.2
#
# Line 1 - `mass` = 47.5, `age` is undefined
# Line 2 - `mass` = 47.5, `age` = 122
# Line 3 - `mass` = 95, `age` = 122
# Line 4 - `mass` = 95, `age` = 102
#
# ## Exercise 01.3
#
# ```Python
# result = 0
# # The below is an example; there are multiple ways to do this!
# result = 50 * 8
# result = result + 75
# result = result - (8 + 10)
# result = result + 1
# result
# ```
#
# ## Exercise 01.4
#
# `"Hopper" "Grace"`
#
# # Lesson 02 Radiance Data
#
# ## Exercise 02.1
#
# `string[:4]` -> `"expe"`
#
# `string[4:]` -> `"riment01.csv"`
#
# `string[:]` -> `'experiment01.csv'`
#
# `string[-1]` -> `'v'`
#
# `string[-2]` -> `'s'`
#
# `string[1:-1]` -> `'xperiment01.cs'`

# %%
string = 'experiment.csv'
print(string[-3:])
string = 'carpentry'
print(string[-3:])
string = 'clone'
print(string[-3:])
string = 'hi'
print(string[-3:])
# Out:
# csv
# try
# one
# hi

# %% [markdown]
# ## Exercise 02.2
#
# `array([], shape=(0, 0), dtype=float64)`
#
# `array([], shape=(0, 2), dtype=float64)`
#
# ## Exercise 02.3

# %%
import matplotlib.pyplot as plt


fig = plt.figure()
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)
ax6 = fig.add_subplot(326)

# Annotations are not required for the answer
# They are just a demonstration of the layout
for i, ax in enumerate([ax1, ax2, ax3, ax4, ax5, ax6]):
    ax.annotate(str(i+1), (0.5, 0.5), color='r', fontsize=20)

# %% [markdown]
# ## Exercise 02.4

# %%
import numpy 


ones = numpy.ones((3, 3))
ones = ones * 10
print(ones)
ones = ones - 5
print(ones)
ones = ones / 5
print(ones)
# Out:
# [[10. 10. 10.]
#  [10. 10. 10.]
#  [10. 10. 10.]]
# [[5. 5. 5.]
#  [5. 5. 5.]
#  [5. 5. 5.]]
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
twos = numpy.ones((3, 3)) + 1
print(twos+ones)
print(twos*ones)
print(ones/twos)
# Out:
# [[3. 3. 3.]
#  [3. 3. 3.]
#  [3. 3. 3.]]
# [[2. 2. 2.]
#  [2. 2. 2.]
#  [2. 2. 2.]]
# [[0.5 0.5 0.5]
#  [0.5 0.5 0.5]
#  [0.5 0.5 0.5]]

# %%
threes = numpy.ones((5, 5))*3
threes + ones
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-2b1d5a7f734b> in <module>
#       1 threes = numpy.ones((5, 5))*3
# ----> 2 threes + ones
#
# ValueError: operands could not be broadcast together with shapes (5,5) (3,3)

# %% [markdown]
# # Lesson 03 Repeating Actions with Loops
#
# ## Exercise 03.1

# %%
for i in range(1, 4):
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## Exercise 03.2
# - 6 times
#
# ## Exercise 03.3

# %%
result = 1
for i in range(3):
    result = result * 5
result
# Out:
# 125

# %% [markdown]
# ## Exercise 03.4

# %%
s = 'Newton'
new = ''
for char in s:
    new = char + new
new
# Out:
# 'notweN'

# %% [markdown]
# ## Exercise 03.5

# %%
x = 5
coefs = [2, 4, 3]
y = 0
for i, coefficient in enumerate(coefs):
    y += coefficient * x**i
print(y)
# Out:
# 97

# %% [markdown]
# # Lesson 04 Lists
#
# ## Exercise 04.1

# %%
fruits = ['apple', 'orange', 'banana', 'kumquat']
my_fruits = []
for f in fruits:
    my_fruits.append(f)
my_fruits[0] = 'plum'
print('The fruits I can eat are: ', my_fruits)
# output should read:
# The fruits I can eat are:  ['plum', 'orange', 'banana', 'kumquat']
# Out:
# The fruits I can eat are:  ['plum', 'orange', 'banana', 'kumquat']

# %% [markdown]
# ## Exercise 04.2

# %%
my_list = []
for c in 'hello':
    my_list.append(c)
my_list
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %% [markdown]
# ## Exercise 04.3

# %%
string_for_slicing = 'Observation date: 02-Feb-2013'
list_for_slicing = [['fluorine', 'F'],
                    ['chlorine', 'Cl'],
                    ['bromine', 'Br'],
                    ['iodine', 'I'],
                    ['astatine', 'At']]

string_for_slicing[-4:], list_for_slicing[-4:]
# Out:
# ('2013',
#  [['chlorine', 'Cl'], ['bromine', 'Br'], ['iodine', 'I'], ['astatine', 'At']])

# %% [markdown]
# This would work for strings of any length
#
# ## Exercise 04.4

# %%
counts = [2, 4, 6, 8, 10]
repeats = counts * 2
print(repeats)
# Out:
# [2, 4, 6, 8, 10, 2, 4, 6, 8, 10]

# %% [markdown]
# ## Exercise 04.5

# %%
beatles = "In an octopus's garden in the shade"
beatles[::2]
# Out:
# 'I notpssgre ntesae'

# %% [markdown]
# ## Exercise 04.5 (Harder)

# %%
queue = ['Jean', 'Brutus', 'Imhotep', 'Lord Scotland', 'Millsy']
queue[::-1]
# Out:
# ['Millsy', 'Lord Scotland', 'Imhotep', 'Brutus', 'Jean']

# %% [markdown]
# # Lesson 5 Making Choices
#
# ## Exercise 05.1
#
# 1. A - after the first `if`, python doesn't bother with any further statements, even if they are `True`.

# %%
if 4 > 3:
    print('A')
elif 4 == 5:
    print('B')
elif 4 < 5:
    print('C')
# Out:
# A

# %% [markdown]
# ## Ejercicio 05.2
#
# Las listas vacías, las cadenas vacías y el entero `0` son falsy.
#
# Las listas pobladas, cadenas y el entero `1` son veraces.
#
# ## Ejercicio 05.3
#
# El usuario Check ha utilizado correctamente la sentencia `not` y `bool` (opcional) y la función respectivamente en su código.
#
# ## Ejercicio 05.4

# %%
import numpy as np

# numpy tiene un generador de números aleatorios incorporado. Aquí lo usamos para crear una matriz 5x5 donde los elementos son aleatorios
# tomado de la distribución normal estándar (media=0, stdev=1)
# primero arreglamos la semilla de números aleatorios para que obtengamos los mismos resultados cada vez!
np.random.seed(1)
A = np.random.randn(5,5)
B = np.arange(25)
# we can reshape numpy arrays using np.reshape
B = np.reshape(B, (5,5))

print(B[A>0])
print(B[A<0])


# result is always 1D, or "flat". Boolean casting does NOT slice the array
# Out:
# [ 0  4  6  8 10 14 18 19 21 22 23 24]
# [ 1  2  3  5  7  9 11 12 13 15 16 17 20]

# %% [markdown]
# ## Exercise 05.5

# %%
import numpy as np
import matplotlib.pyplot as plt


# load in the data as we did previously
sim = np.loadtxt(fname='../simulation01.txt', skiprows=52)
x = sim[:, 0]
y = sim[:, 1]
rad = sim[:, 2]

# Find the closest y-value to 0
smallest_y1 = -0.25
smallest_y2 = 0.25

# doesn't work
# L = y[y==smallest_y1 or y==smallest_y2]

np.logical_or(y==smallest_y1, y==smallest_y2)
# Out:
# array([False, False, False, ..., False, False, False])

# %% [markdown]
# ## Exercise 05.6

# %%
positive_sum = 0
negative_sum = 0
test_list = [3, 4, 6, 1, -1, -5, 0, 7, -8]
for num in test_list:
    if num > 0:
        positive_sum += num
    elif num == 0:
        pass
    else:
        negative_sum += num
print(positive_sum, negative_sum)
# Out:
# 21 -14

# %% [markdown]
# # Lesson 06 Glob
#
# ## Exercise 06.1

# %%
import glob

glob.glob('*.ipynb')

# Dos caracteres parecen ser el mínimo. Esto fue probado en cuadernos 
# la carpeta sin comprimir, sin alterar, materiales del curso. Este cuaderno debe estar en 
# esa misma carpeta para que esta respuesta funcione
glob.glob('0*')

# %% [markdown]
# expected output:
#
# ```Python
# >>> glob.glob('*.ipynb')
#
# ['01Fundamentals.ipynb',
#  '02AnalyzingRadianceData.ipynb',
#  '03RepeatingActionsWithLoops.ipynb',
#  '04StoringMultipleValuesInLists.ipynb',
#  '05MakingChoices.ipynb',
#  '06AnalyzingDataFromMultipleFiles.ipynb',
#  '07CreatingFunctions.ipynb',
#  '08DefensiveProgramming.ipynb',
#  '09Debugging.ipynb',
#  '10CommandLinePrograms.ipynb']
# ```

# %% [markdown]
# ## Exercise 06.2

# %%
import numpy as np
import matplotlib.pyplot as plt


sim = np.loadtxt(fname='../simulation02.txt', skiprows=52)
x = sim[:, 0]
y = sim[:, 1]
rad = sim[:, 2]
# Find the closest y-value to 0
smallest_y = np.amin(abs(y))
x_cross_section = x[y==smallest_y]

luminance_cross_section02 = rad[y==smallest_y]

sim = np.loadtxt(fname='../simulation04.txt', skiprows=52)
x = sim[:, 0]
y = sim[:, 1]
rad = sim[:, 2]
# Find the closest y-value to 0
smallest_y = np.amin(abs(y))
x_cross_section = x[y==smallest_y]

luminance_cross_section04 = rad[y==smallest_y]


diff = luminance_cross_section02 - luminance_cross_section04
plt.plot(x_cross_section, diff)

# %% [markdown]
# ## Exercise 06.3

# %%
import numpy as np
import glob


filenames = glob.glob('../simulation*.txt')
experiment = numpy.loadtxt(fname='../experiment01.csv', delimiter=',')
x_exp = experiment[:, 0]
L_exp = experiment[:, 1]
for filename in filenames:
    sim = np.loadtxt(fname=filename, skiprows=52)
    x = sim[:, 0]
    y = sim[:, 1]
    rad = sim[:, 2]
    # Find the closest y-value to 0
    smallest_y = np.amin(abs(y))
    x_cross_section = x[y==smallest_y]
    L = rad[y==smallest_y]
    
    sim_mean = np.mean(L[np.logical_and(x_cross_section>=-10., x_cross_section<=10.)])
    exp_mean = np.mean(L_exp[np.logical_and(x_exp>=-10., x_exp<=10.)])
    
    diff = (sim_mean - exp_mean)*100./exp_mean
    print(diff)
    
# Enter your solution here
# Note: percentage difference should be = (difference between the values/experimental value)*100
# Out:
# 3.319310065215488
# -77.88975272561785
# -42.73462211252939
# -82.72425871918331
# -81.94342576807645

# %% [markdown]
# ## Exercise 06.4

# %%
fig1 = plt.figure(figsize=(16,8))
fig2 = plt.figure(figsize=(16,8))

filenames = sorted(glob.glob('../simulation*.txt'))
for i, filename in enumerate(filenames):
    print(filename)

    sim = np.loadtxt(fname=filename, skiprows=52)
    x = sim[:, 0]
    y = sim[:, 1]
    rad = sim[:, 2]
    smallest_y = np.amin(abs(y))
    x_cross_section = x[y==smallest_y]
    luminance_cross_section = rad[y==smallest_y]

    ax1 = fig1.add_subplot(3,2,i+1)
    ax2 = fig2.add_subplot(3,2,i+1)
    
    sc = ax1.scatter(x, y, c=rad, vmin=0, vmax=350000)
    cb = fig.colorbar(sc, ax=ax1)
    
    ax2.plot(x_cross_section, luminance_cross_section)
    
    ax1.set_ylabel('y position [mm]')
    ax1.set_xlabel('x position [mm]')
    
    ax2.set_ylabel('Luminance [Cd/m^2]')
    ax2.set_xlabel('x position [mm]')
    
    cb.set_label('Luminance [Cd/m^2]')
    
    ax1.set_title(filename)
    ax2.set_title(filename)

    ax1.set_aspect(1)
    
    
fig1.tight_layout()
fig2.tight_layout()
# Out:
# ..\simulation01.txt
# ..\simulation02.txt
# ..\simulation03.txt
# ..\simulation04.txt
# ..\simulation05.txt

# %% [markdown]
# # Lesson 07 Functions
#
# ## Exercise 07.1

# %%
def fence(original, wrapper):
    return wrapper + original + wrapper

fence('name', '*')
# Out:
# '*name*'

# %% [markdown]
# ## Ejercicio 07.2
#
# 1. La función se ejecutará
#
# 2. No se imprimirá nada porque la función no devuelve nada.
#
# ## Ejercicio 07.3

# %%
def outer(input_string):
    return input_string[0]+input_string[-1]

outer('helium')
# Out:
# 'hm'

# %% [markdown]
# ## Exercise 07.4

# %%
import numpy as np


def rescale(array):
    max_ = np.amax(array)
    min_ = np.amin(array)
    scaled = (array-min_)/(max_ - min_)
    return scaled


test = np.arange(10)

rescale(test)
# Out:
# array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])

# %% [markdown]
# ## Ejercicio 07.5
#
# - cualquier texto sensato está bien, véase [here](https://github.com/pyansys/pymapdl/blob/main/ansys/mapdl/core/inline_functions/line_queries.py) for an example
#
#
# For the `normalise` or `rescale` function:
#
# ```Python
# def rescale(array):
#     """Return the array scaled to be between 0 and 1 inclusive, elementwise."""
#     max_ = np.amax(array)
#     min_ = np.amin(array)
#     scaled = (array-min_)/(max_ - min_)
#     return scaled
#
# ```
#
# ## Exercise 07.6

# %%
def rescale(array, lower=0., upper=1.):
    max_ = np.amax(array)
    min_ = np.amin(array)
    scaled = (array-min_)/(max_ - min_)
    
    range_ = upper-lower
    scaled *= range_
    scaled += lower
    return scaled


test = np.arange(10)

rescale(test, lower=1, upper=200)
# Out:
# array([  1.        ,  23.11111111,  45.22222222,  67.33333333,
#         89.44444444, 111.55555556, 133.66666667, 155.77777778,
#        177.88888889, 200.        ])

# %% [markdown]
# ## Exercise 07.7

# %%
f = 0
k = 0

def f2k(f):
    k = ((f - 32) * (5.0 / 9.0)) + 273.15
    return k

print(f2k(8))
print(f2k(41))
print(f2k(32))

print(k)
# Out:
# 259.81666666666666
# 278.15
# 273.15
# 0

# %% [markdown]
# ## Exercise 07.8
#
# - `SyntaxError`
# - number 3, `a: -1 b: 2 c: 6`

# %% [markdown]
# Lección 08 Programación defensiva
#
# ## Ejercicio 08.1
#
# Muchas respuestas correctas aquí. Ejemplos:
#
# Condiciones previas:
#
# - la entrada es numérica
# - más de una aportación
# - Los números se indican en una lista y no en otra cosa
#
# Postcondiciones
#
# - la producción es numérica
# - la lista de entrada no ha cambiado (de lo contrario las referencias a ella podrían verse afectadas!)
# - El resultado es válido (p. ej., no complejo si no se trata de números complejos)
#
# ## Ejercicio 08.2

# %%
def get_total(values):
    # checks that some values are provided; an empty list would fail it
    assert len(values) > 0
    for element in values:
        # checks the element of the list can be converted to an integer and greater than 0. 0.1 would fail.
        assert int(element) > 0, "element must be > 0"
    values = [int(element) for element in values]
    total = sum(values)
    # checks the final total equals a value greater than 0. an all negative numbers list will fail here
    # if it gets that far
    assert total > 0
    return total

get_total([-1, -2])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-62-9162ce6d81ae> in <module>
#      11     return total
#      12
# ---> 13 get_total([-1, -2])
#
# <ipython-input-62-9162ce6d81ae> in get_total(values)
#       4     for element in values:
#       5         # checks the element of the list can be converted to an integer and greater than 0. 0.1 would fail.
# ----> 6         assert int(element) > 0, "element must be > 0"
#       7     values = [int(element) for element in values]
#       8     total = sum(values)
#
# AssertionError: element must be > 0

# %% [markdown]
# # Lesson 09 Debugging
#
# ## Exercise 09.1

# %%
# Ejercicio 1* - Trazando diferencias

# Traza la diferencia entre los radiancias encontrados en las simulaciones 02 y 04.

# 1. Carga ambos desde csv
# 2. Extraer las secciones transversales de radiancia a lo largo de la misma ubicación
# 3. Tome la diferencia entre las dos matrices y trace


import numpy as np
import matplotlib.pyplot as plt


# no delimiter needed
# sim = np.loadtxt(fname='../simulation02.txt', skiprows=52, delimiter=',')
sim = np.loadtxt(fname='../simulation02.txt', skiprows=52)
x = sim[:, 0]
y = sim[:, 1]
# should be index of 2 not 3
# rad = sim[:, 3]
rad = sim[:, 2]
# Find the closest y-value to 0
smallest_y = np.amin(abs(y))
x_cross_section = x[y==smallest_y]

luminance_cross_section02 = rad[y==smallest_y]

# delimiter again
# AND comparing simulation 03 not 04
# sim = np.loadtxt(fname='../simulation03.txt', skiprows=52, delimiter=',')
sim = np.loadtxt(fname='../simulation04.txt', skiprows=52)
x = sim[:, 0]
y = sim[:, 1]
# index again
# rad = sim[:, 3]
rad = sim[:, 2]
# Find the closest y-value to 0
smallest_y = np.amin(abs(y))
x_cross_section = x[y==smallest_y]

luminance_cross_section04 = rad[y==smallest_y]


diff = luminance_cross_section02 - luminance_cross_section04
plt.plot(x_cross_section, diff)

# %% [markdown]
# ## Exercise 09.2

# %%
patients = [[70, 1.8], [80, 1.9], [150, 1.7]]

def calculate_bmi(weight, height):
    return weight / (height ** 2)

for patient in patients:
    # following line is wrong
    # weight, height = patients[0]
    # should be
    weight, height = patient
    # next line is wrong
    # bmi = calculate_bmi(height, weight)
    # should be
    bmi = calculate_bmi(weight, height)
    print("Patient's BMI is: %f" % bmi)
# Out:
# Patient's BMI is: 21.604938
# Patient's BMI is: 22.160665
# Patient's BMI is: 51.903114

# %% [markdown]
# #Lección 10
#
# ## Ejercicio 10.1
#
# Ninguna de las respuestas de este cuaderno funcionará aquí, ya que todas están diseñadas para ejecutarse como scripts independientes en la línea de comandos. Sin embargo, el código es correcto.

# %%
import sys

action = sys.argv[1]

arg1 = sys.argv[2]
arg2 = sys.argv[3]

if action == 'add':
    print(float(arg1) + float(arg2))
elif action == 'subtract':
    print(float(arg1) - float(arg2))
else:
    raise TypeError

# %% [markdown]
# ## Exercise 10.2

# %%
import sys
import glob

extension = sys.argv[1]

files = glob.glob('./*'+extension)
for f in files:
    print(f)

# %% [markdown]
# ## Exercise 10.3

# %%
import sys
import numpy as np


def find_data_cross_section(simulation_filename):
    simulation = np.loadtxt(fname=simulation_filename, skiprows=52)

    x_simulation = simulation[:, 0]
    y_simulation = simulation[:, 1]
    L_simulation = simulation[:, 2]
    smallest_y = np.amin(abs(y_simulation))
    x_cross_section = x_simulation[y_simulation==smallest_y]
    luminance_cross_section = L_simulation[y_simulation==smallest_y]
    
    return x_cross_section, luminance_cross_section


# we introduce a new function to load the experimental data
def load_experiment_data(experiment_filename):
    experiment = np.loadtxt(fname=experiment_filename, delimiter=',')
    return experiment[:,0], experiment[:,1]


def calculate_luminance_stats(x, luminance, action):
    boolean_array = np.logical_and(x<=10., x>= -10.)
    if action == '--mean':
        statistic = np.mean(luminance[boolean_array])
    elif action == '--std':
        statistic = np.std(luminance[boolean_array])
    else:
        raise TypeError('No valid action supplied (allowed actions are "--mean" or "--std")')
    return statistic


def main():
    if len(sys.argv) == 1:
        print('Args required here are...')
    else:
        action1 = sys.argv[1]
        action2 = sys.argv[2]

        if action2 == '--experiment':
            experiment_filename = sys.argv[3]
            x_experiment, luminance_experiment = load_experiment_data(experiment_filename)
            filenames = sys.argv[4:]
        else:
            experiment_filename = ''
            filenames = sys.argv[2:]

        for filename in filenames:
            x, luminance = find_data_cross_section(filename)
            simulation_statistic = calculate_luminance_stats(x, luminance, action1)
            print(action1[2:] + ' luminance for ' + filename + ' = ' + str(simulation_statistic) + ' Cd/m^2')
            if bool(experiment_filename):
                experiment_statistic = calculate_luminance_stats(x_experiment, luminance_experiment, action1)
                perc_diff = (experiment_statistic - simulation_statistic)*100/experiment_statistic
                print('Percentage difference with experimental value = ' + str(perc_diff) + ' %')

    
if __name__ == '__main__':
   main()

# %% [markdown]
# ## Exercise 10.4

# %%
import sys
import numpy as np


def find_data_cross_section(simulation_filename):
    simulation = np.loadtxt(fname=simulation_filename, skiprows=52)

    x_simulation = simulation[:, 0]
    y_simulation = simulation[:, 1]
    L_simulation = simulation[:, 2]
    smallest_y = np.amin(abs(y_simulation))
    x_cross_section = x_simulation[y_simulation==smallest_y]
    luminance_cross_section = L_simulation[y_simulation==smallest_y]
    
    return x_cross_section, luminance_cross_section


# we introduce a new function to load the experimental data
def load_experiment_data(experiment_filename):
    experiment = np.loadtxt(fname=experiment_filename, delimiter=',')
    return experiment[:,0], experiment[:,1]


def calculate_luminance_stats(x, luminance, action):
    boolean_array = np.logical_and(x<=10., x>= -10.)
    if action == '--mean':
        statistic = np.mean(luminance[boolean_array])
    elif action == '--std':
        statistic = np.std(luminance[boolean_array])
    else:
        raise TypeError('No valid action supplied (allowed actions are "--mean" or "--std")')
    return statistic


def main():
    action1 = sys.argv[1]
    action2 = sys.argv[2]
    if action1 not in ['--mean', '--std']:
        action1 = '--mean'
    
    if action2 == '--experiment':
        experiment_filename = sys.argv[3]
        x_experiment, luminance_experiment = load_experiment_data(experiment_filename)
        filenames = sys.argv[4:]
    else:
        experiment_filename = ''
        filenames = sys.argv[2:]
        
    for filename in filenames:
        x, luminance = find_data_cross_section(filename)
        simulation_statistic = calculate_luminance_stats(x, luminance, action1)
        print(action1[2:] + ' luminance for ' + filename + ' = ' + str(simulation_statistic) + ' Cd/m^2')
        if bool(experiment_filename):
            experiment_statistic = calculate_luminance_stats(x_experiment, luminance_experiment, action1)
            perc_diff = (experiment_statistic - simulation_statistic)*100/experiment_statistic
            print('Percentage difference with experimental value = ' + str(perc_diff) + ' %')

    
if __name__ == '__main__':
   main()

# %% [markdown]
# ## Exercise 10.5

# %%
import sys


if len(sys.argv)==1:
    print('usage python check_arguments.py filename.txt')
elif len(sys.argv)>1:
    print('Thanks for specifying arguments!')
# Out:
# Thanks for specifying arguments!
